# %%
import json
import requests

# %%
username='pratik-chakraborty10'
url='https://api.github.com/users/{}'.format(username)
print(url)
# Out:
# https://api.github.com/users/pratik-chakraborty10

# %%
response=requests.get(url)
print(response.status_code)
# Out:
# 200

# %%
print(response.json())
# Out:
# {'login': 'pratik-chakraborty10', 'id': 118681019, 'node_id': 'U_kgDOBxLtuw', 'avatar_url': 'https://avatars.githubusercontent.com/u/118681019?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/pratik-chakraborty10', 'html_url': 'https://github.com/pratik-chakraborty10', 'followers_url': 'https://api.github.com/users/pratik-chakraborty10/followers', 'following_url': 'https://api.github.com/users/pratik-chakraborty10/following{/other_user}', 'gists_url': 'https://api.github.com/users/pratik-chakraborty10/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/pratik-chakraborty10/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/pratik-chakraborty10/subscriptions', 'organizations_url': 'https://api.github.com/users/pratik-chakraborty10/orgs', 'repos_url': 'https://api.github.com/users/pratik-chakraborty10/repos', 'events_url': 'https://api.github.com/users/pratik-chakraborty10/events{/privacy}', 'received_events_url': 'https://api.github.com
# ...

# %%
print(type(response.text))
# Out:
# <class 'str'>

# %%
output=response.json()
print(type(output))
# Out:
# <class 'dict'>

# %%
print(output)
# Out:
# {'login': 'pratik-chakraborty10', 'id': 118681019, 'node_id': 'U_kgDOBxLtuw', 'avatar_url': 'https://avatars.githubusercontent.com/u/118681019?v=4', 'gravatar_id': '', 'url': 'https://api.github.com/users/pratik-chakraborty10', 'html_url': 'https://github.com/pratik-chakraborty10', 'followers_url': 'https://api.github.com/users/pratik-chakraborty10/followers', 'following_url': 'https://api.github.com/users/pratik-chakraborty10/following{/other_user}', 'gists_url': 'https://api.github.com/users/pratik-chakraborty10/gists{/gist_id}', 'starred_url': 'https://api.github.com/users/pratik-chakraborty10/starred{/owner}{/repo}', 'subscriptions_url': 'https://api.github.com/users/pratik-chakraborty10/subscriptions', 'organizations_url': 'https://api.github.com/users/pratik-chakraborty10/orgs', 'repos_url': 'https://api.github.com/users/pratik-chakraborty10/repos', 'events_url': 'https://api.github.com/users/pratik-chakraborty10/events{/privacy}', 'received_events_url': 'https://api.github.com
# ...

# %%
output['avatar_url']
# Out:
# 'https://avatars.githubusercontent.com/u/118681019?v=4'

# %%
# image save in current working directory

response_img=requests.get(output['avatar_url'])

foo=open('{}_img.png'.format(username),'wb')
foo.write(response_img.content)
foo.close()

# %%
from skimage import io
img_url=output['avatar_url']

img=io.imread(img_url)
io.imshow(img)
